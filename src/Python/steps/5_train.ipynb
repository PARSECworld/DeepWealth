# %% [markdown]
# Prerequisites:
# 1. Run `steps/1_process_tfrecords.ipynb`
# 2. Run `steps/2_create_incountry_folds.ipynb` to create the `dhs_incountry_folds.pkl`.
# 3. Run `steps/3_dhs_baselines.ipynb` to create the `dhs_image.npz`.
# 4. Run `steps/4_dhs.ipynb` to create the `dhs_loc_dict.pkl`.

# %% [markdown]
# # Imports and Constants

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# change directory to repo root, and verify
# %cd '/hdd/home/abenabbes/Ali-a'
# !pwd

# %%
#DHS_Incountry_A_nl

# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_A_nl_random \
        --dataset DHS_incountry_A \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS_Incountry_B_nl

# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_B_nl_random \
        --dataset DHS_incountry_B \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS_Incountry_C_nl

# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_C_nl_random \
        --dataset DHS_incountry_C \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS_Incountry_D_nl
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_D_nl_random \
        --dataset DHS_incountry_D \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS_Incountry_E_nl
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_E_nl_random \
        --dataset DHS_incountry_E \
        --nl_band split \
        --lr 0.001 --fc_reg 0.1 --conv_reg 1.0

# %%
#DHS incountry MS A (2000-2019)
#change the path of --imagenet_weights_path for all next scripts

# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_A_ms_samescaled \
        --dataset DHS_incountry_A \
        --ls_band ms \
        --lr 0.001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
# to DHS incountry MS B (1996-2019) fait /terminal 


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_B_ms_samescaled\
        --dataset DHS_incountry_B \
        --ls_band ms \
        --lr 0.001 --fc_reg 0.1 --conv_reg 0.1 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry MS C (1996-2016)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_C_ms_samescaled\
        --dataset DHS_incountry_C \
        --ls_band ms \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry MS D (1996-2016)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_D_ms_samescaled\
        --dataset DHS_incountry_D \
        --ls_band ms \
        --lr 0.0001 --fc_reg 0.001 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry MS E (1996-2019)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_E_ms_samescaled\
        --dataset DHS_incountry_E \
        --ls_band ms \
        --lr 0.0001 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC MS A (1996-2019)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_A_ms_samescaled \
        --dataset DHS_OOC_A \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC MS B (1996-2019)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_B_ms_samescaled \
        --dataset DHS_OOC_B \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC MS C (1996-2019)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 200 \
         --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_C_ms_samescaled \
        --dataset DHS_OOC_C \
        --ls_bands ms \
        --lr 0.001 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC MS D (1996-2019)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_D_ms_samescaled \
        --dataset DHS_OOC_D \
        --ls_bands ms \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC MS E (1996-2019)

# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_E_ms_samescaled \
        --dataset DHS_OOC_E \
        --ls_bands ms \
        --lr 0.001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry RGB A (1996-2019)-----


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150\
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_A_rgb_same \
        --dataset DHS_incountry_A \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry RGB B (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150\
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_B_rgb_same \
        --dataset DHS_incountry_B \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry RGB C (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150\
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_C_rgb_same \
        --dataset DHS_incountry_C \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry RGB D (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150\
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_D_rgb_same \
        --dataset DHS_incountry_D \
        --ls_band rgb \
        --lr 0.01 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS incountry RGB E (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150\
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhsincountry/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_Incountry_E_rgb_same \
        --dataset DHS_incountry_E \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC A NL (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_A_nl_random \
        --ooc \
        --dataset DHS_OOC_A \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS OOC B NL (1996-2019)


# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_B_nl_random \
        --ooc \
        --dataset DHS_OOC_B \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS OOC C NL (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_C_nl_random \
        --ooc \
        --dataset DHS_OOC_C \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS OOC D NL (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_D_nl_random \
        --ooc \
        --dataset DHS_OOC_D \
        --nl_band split \
        --lr 0.01 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS OOC E NL (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_E_nl_random \
        --ooc \
        --dataset DHS_OOC_E \
        --nl_band split \
        --lr 0.0001 --fc_reg 1.0 --conv_reg 1.0

# %%
#DHS OOC A RGB (1996-2019)

# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_A_rgb_same \
        --dataset DHS_OOC_A \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC B RGB (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_B_rgb_same \
        --dataset DHS_OOC_B \
        --ooc \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC C RGB (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_C_rgb_same \
        --dataset DHS_OOC_C \
        --ooc \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC D RGB (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /hdd/home/abenabbes/final_ex/nouveau/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_D_rgb_same \
        --dataset DHS_OOC_D \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 1.0 --conv_reg 1.0 \
        --imagenet_weights_path /hdd/home/abenabbes/africapoverty/ImageNet-ResNet18.npz

# %%
#DHS OOC E RGB (1996-2019)
# !python train_direct.py \
        --label_name wealthpooled \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 200 \
        --out_dir /home/abenabbes/final_ex/dhs/ \
        --keep_frac 1.0 --seed 123 \
        --experiment_name DHS_OOC_E_rgb_same \
        --dataset DHS_OOC_E \
        --ooc \
        --ls_band rgb \
        --lr 0.0001 --fc_reg 0.001 --conv_reg 0.001 \
         --imagenet_weights_path /home/abenabbes/africapoverty/ImageNet-ResNet18.npz
